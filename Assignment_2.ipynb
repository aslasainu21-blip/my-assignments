# %%
age_list = [24, 25, 26, 27, 28]
name_list = ["Aswin", "Binu", "Ciya", "Deepa", "Esha"]
print("Age List:", age_list)
print("Name List:", name_list)
# Out:
# Age List: [24, 25, 26, 27, 28]
# Name List: ['Aswin', 'Binu', 'Ciya', 'Deepa', 'Esha']

# %%
name_list.append("Yazhini")
age_list.insert(2, 30)
name_list.remove("Yazhini")
age_list.pop()
age_list.extend([29, 30, 26])
age_list.sort(reverse=True)

print("Age List:", age_list)
print("Name List:", name_list)
print(max(age_list))
print(min(age_list))
print(sum(age_list))
# Out:
# Age List: [30, 30, 30, 30, 30, 30, 29, 29, 29, 27, 26, 26, 26, 26]
# Name List: ['Aswin', 'Binu', 'Ciya', 'Deepa', 'Esha']
# 30
# 26
# 398

# %%
print(name_list[0])
print(name_list[-1])
print(name_list[2:5])
print(name_list[::-1])
# Out:
# Aswin
# Esha
# ['Ciya', 'Deepa', 'Esha']
# ['Esha', 'Deepa', 'Ciya', 'Binu', 'Aswin']

# %%
student_marks = {
    "Aswin": 85,
    "Binu": 90,
    "Ciya": 78,
    "Deepa": 92,
    "Esha": 88
}
print(student_marks["Binu"])

student_marks["Janani"] = 80
student_marks["Ciya"] = 82

print(list(student_marks.keys()))
print(list(student_marks.values()))
print(list(student_marks.items()))
# Out:
# 90
# ['Aswin', 'Binu', 'Ciya', 'Deepa', 'Esha', 'Janani']
# [85, 90, 82, 92, 88, 80]
# [('Aswin', 85), ('Binu', 90), ('Ciya', 82), ('Deepa', 92), ('Esha', 88), ('Janani', 80)]

# %%
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}
print(my_set)

try:
    my_set[4] = 's'
except TypeError:
    pass

set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {'u', 'a', 'e', 'i', 'o'}
# {1, 2, 3, 5, 7, 8, 9, 10}
# {3, 5}

# %%
score = float(input("Enter your score (0 to 10): "))

if score > 7 and score <= 10:
    print("Above Average: Excellent work! Keep it up.")
elif score >= 4 and score <= 7:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
elif score >= 0 and score < 4:
    print("Below Average: Need to Improve your performance, consistent practice will lead to better results.")
else:
    print("Invalid score! Please enter between 0 to 10.")
# Out:
# Enter your score (0 to 10): 9
# Above Average: Excellent work! Keep it up.

# %%
score = float(input("Enter your score (0 to 10): "))

if score > 7 and score <= 10:
    print("Above Average: Excellent work! Keep it up.")
elif score >= 4 and score <= 7:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
elif score >= 0 and score < 4:
    print("Below Average: Need to Improve your performance, consistent practice will lead to better results.")
else:
    print("Invalid score! Please enter between 0 to 10.")
# Out:
# Enter your score (0 to 10): 6
# Average: Good effort! Keep practicing, there's room for improvement.

# %%
score = float(input("Enter your score (0 to 10): "))

if score > 7 and score <= 10:
    print("Above Average: Excellent work! Keep it up.")
elif score >= 4 and score <= 7:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
elif score >= 0 and score < 4:
    print("Below Average: Need to Improve your performance, consistent practice will lead to better results.")
else:
    print("Invalid score! Please enter between 0 to 10.")
# Out:
# Enter your score (0 to 10): 2
# Below Average: Need to Improve your performance, consistent practice will lead to better results.

# %%
score = float(input("Enter your score (0 to 10): "))

if score > 7 and score <= 10:
    print("Above Average: Excellent work! Keep it up.")
elif score >= 4 and score <= 7:
    print("Average: Good effort! Keep practicing, there's room for improvement.")
elif score >= 0 and score < 4:
    print("Below Average: Need to Improve your performance, consistent practice will lead to better results.")
else:
    print("Invalid score! Please enter between 0 to 10.")
# Out:
# Enter your score (0 to 10): 11
# Invalid score! Please enter between 0 to 10.
