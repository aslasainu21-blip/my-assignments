# %%
name = "Zara"
str1 = "Hello "
str3 = ", welcome to Python programming"
result = str1 + name + str3
print(result)
# Out:
# Hello Zara, welcome to Python programming

# %%
print("First char:", result[0])
print("Last char:", result[-1])
print("First 5 chars:", result[:5])
print("Last 11 chars:", result[-11:])
print("Reverse:", result[::-1])
print("Python word:", result[13:19])
# Out:
# First char: H
# Last char: g
# First 5 chars: Hello
# Last 11 chars: programming
# Reverse: gnimmargorp nohtyP ot emoclew ,araZ olleH
# Python word: elcome

# %%
strM = "Python beginner tutorial"
print(strM.upper())
print(strM.lower())
print(strM.capitalize())
print(strM.count('t'))
print(strM.replace("Python", "Machine Learning"))
# Out:
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# 3
# Machine Learning beginner tutorial

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)
t_combine = t1 + t2
print(t_combine)
print(t_combine * 3)
print(t_combine[2])
print(t_combine[:3])
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)
